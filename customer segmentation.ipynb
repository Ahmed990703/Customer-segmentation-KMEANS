# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
df=pd.read_excel('/Users/ahmedmaher/Desktop/Online Retail.xlsx')

# %%
df.head(6)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom

# %%
df.drop(['StockCode','InvoiceNo','CustomerID'],axis=1,inplace=True)

# %%
df.head(6)
# Out:
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# 5         SET 7 BABUSHKA NESTING BOXES         2 2010-12-01 08:26:00
#
#    UnitPrice         Country
# 0       2.55  United Kingdom
# 1       3.39  United Kingdom
# 2       2.75  United Kingdom
# 3       3.39  United Kingdom
# 4       3.39  United Kingdom
# 5       7.65  United Kingdom

# %%
df.isna().sum()
# Out:
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# Country           0
# dtype: int64

# %%
import seaborn as sns

# %%
from sklearn.impute import SimpleImputer
mod=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
df['Description']=mod.fit_transform(df['Description'].values.reshape(-1,1))

# %%
df.isna().sum()
# Out:
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
df.dtypes
# Out:
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# Country                object
# dtype: object

# %%
df['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     3823
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: Description, Length: 4223, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Description']=df['Description'].astype(str)
df['InvoiceDate']=df['InvoiceDate'].astype(str)

# %%
df['Description']=le.fit_transform(df['Description'])
df['Country']=le.fit_transform(df['Country'])

# %%
df['InvoiceDate']=le.fit_transform(df['InvoiceDate'])

# %%
df.dtypes
# Out:
# Description      int64
# Quantity         int64
# InvoiceDate      int64
# UnitPrice      float64
# Country          int64
# dtype: object

# %%
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_43c6b_row0_col0, #T_43c6b_row1_col1, #T_43c6b_row2_col2, #T_43c6b_row3_col3, #T_43c6b_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_43c6b_row0_col1, #T_43c6b_row1_col3, #T_43c6b_row2_col3, #T_43c6b_row2_col4, #T_43c6b_row3_col1, #T_43c6b_row4_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_43c6b_row0_col2, #T_43c6b_row1_col0, #T_43c6b_row2_col1, #T_43c6b_row3_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_43c6b_row0_col3, #T_43c6b_row0_col4, #T_43c6b_row1_col4, #T_43c6b_row3_col0, #T_43c6b_row3_col2, #T_43c6b_row4_col0, #T_43c6b_row4_col1, #T_43c6b_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_43c6b_row1_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_43c6b_row2_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_43c6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
sns.pairplot(df)
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df

# %%
df.isna().sum()
# Out:
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
mo_fr=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
df['Description'] = df['Description'].astype(str)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['InvoiceDate']=le.fit_transform(df['InvoiceDate'].values.reshape(-1,1))
df['Country']=le.fit_transform(df['Country'].values.reshape(-1,1))
df['Description']=le.fit_transform(df['Description'].values.reshape(-1,1))
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.dtypes
# Out:
# Description      int64
# Quantity         int64
# InvoiceDate      int64
# UnitPrice      float64
# Country          int64
# dtype: object

# %%
df.head(30)
# Out:
#     Description  Quantity  InvoiceDate  UnitPrice  Country
# 0          3244         6            0       2.55       36
# 1          3253         6            0       3.39       36
# 2          4128         8            0       2.75       36
# 3          1014         6            0       3.39       36
# 4          2126         6            0       3.39       36
# 5          2400         2            0       7.65       36
# 6           590         6            0       4.25       36
# 7           728         6            1       1.85       36
# 8           725         6            1       1.85       36
# 9          1602        32            2       1.69       36
# 10         1939         6            2       2.10       36
# 11         1940         6            2       2.10       36
# 12          325         8            2       3.75       36
# 13          895         6            2       1.65       36
# 14         3744         6            2       4.25       36
# ...

# %%
plt.scatter(x=df['UnitPrice'],y=df['Quantity'])
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.pairplot(df)
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df['Description'].value_counts()

# %%
df.isna().sum()

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler
scl=StandardScaler()

# %%
list_of_intir=[]
for k in range(1,20):
    km=KMeans(n_clusters=k)
    predctions=km.fit_predict(df)
    list_of_intir.append(km.inertia_)
    print(k,km.inertia_)
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 1 27104569875304.24
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2 7005523383186.384
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 3 3469152240210.0713
# ...

# %%
plt.plot(range(1,20),list_of_intir)
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
km=KMeans(n_clusters=6)

# %%
pred=km.fit_predict(df)
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
pred
# Out:
# array([2, 2, 2, ..., 3, 3, 3], dtype=int32)

# %%
plt.scatter(df.iloc[pred==0,2],df.iloc[pred==0,4],color='red')
plt.scatter(df.iloc[pred==1,2],df.iloc[pred==1,4],color='black')
plt.scatter(df.iloc[pred==2,2],df.iloc[pred==2,4],color='blue')
plt.scatter(df.iloc[pred==3,2],df.iloc[pred==3,4],color='yellow')
plt.scatter(df.iloc[pred==4,2],df.iloc[pred==4,4],color='orange')
plt.scatter(df.iloc[pred==5,2],df.iloc[pred==5,4],color='green')
plt.show()
# Out:
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/ahmedmaher/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
